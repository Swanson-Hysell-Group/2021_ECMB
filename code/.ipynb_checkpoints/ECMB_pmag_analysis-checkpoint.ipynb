# %% [markdown]
# # ECMB paleomagnetic data analysis
#
# This notebook analyzes paleomagnetic data developed from dikes of the East Central Minnesota batholith. These data were developed in the UC Berkeley Paleomagnetism lab by Nick Swanson-Hysell, Margaret Avery, Robert Sherwood and Yiming Zhang. Visualizations from this notebook used in manuscript figures are output to the visualizations subfolder.
#
# This Jupyter notebook accompanies the paper:
#
# Swanson-Hysell et al. 2021 **The paleogeography of Laurentia in its early years: new constraints from the Paleoproterozoic East Central Minnesota batholith**

# %%
import pmagpy.ipmag as ipmag
import pmagpy.pmag as pmag
import pandas as pd
pd.set_option('display.max_columns', 500)

import matplotlib.pyplot as plt

# %% [markdown]
# ## Notes associated with fits to ECMB sites
#
# | code | name | color |
# |------|------|-------|
# | lc   | low coercivity | yellowgreen |
# | mc   | medium coercivity | steelblue |
# | hc   | high coercivity | tomato |
#
# - **NED1 (fits are done)** there are small lc components which given a direction roughly consistent with PLF, but they can not be well fit; the mc component is well-resolved; the sample move towards an MCR hc component, but it is small and cannot be fit
# - **NED2 (fits are done)** very nicely resolved mc component with small lc component that is difficult to fit but is roughly consistent with PLF; hc component can be fit usually with a line anchored to the origin and corresponds to MCR direction.
# - **NED3 (fits are done)** mc is aligned with lc and has a poorly grouped non-Fisherian distribution
# - **NED4 (fits are done)** small lc component aligned with PLF; mc is not particularly well-resolved in that the AF demag spectra is not as steep such that there is the possibility that the direction is being convolved with hc which is slightly worrisome as the direction is closer to the hc direction than is typical; some samples can be fit with hc if anchored to origin
# - **NED5 (fits are done)** not very coherent lc direction (shallow and NW); steep ChRM (mc) direction; minimal hc direction that cannot be well fit.
# - **NED6 (fits are done)** site lacks a distinct lc component; mc direction can be fit and often starts at rather low coercivity, but there can be issues with how well it is directionally resolved due to large hc component; large hc direction in Midcontinent Rift direction that can be well-fit in some samples, but is difficult to resolve as a line as it is moving towards endpoint rather than a resolved line that can be fit. As such some of the hc directions are endpoints anchored to the origin.
# - **NED7 (fits are done)** there are large lc overprints on many of these samples that are north and slightly upwards; the large lc directions could potentially cause issues on the mc component, but they are overall well-resolved and tightly grouped; there is a minimal hc component and no fits could be made for it.
# - **NED8 (fits are done)** lc component is typically small and can rarely be fit as it overlaps with the lower coercivity range of the mc component; the mc component dominants the remanence and can be isolated in the middle coercivity range as lines that are well-grouped; there is a high-coercivity phase that is also not well-isolated due to the mc component
# - **NED9 (fits are done)** large lc component of varying magnitude and poorly group direction; nicely resolved mc component; small hc component that can rarely be fit as a line, but it consistent with MCR direction including movement toward that direction when it can't be fit with a line. NED9-1b is nicely behaved, but is a bit of an outlier in terms of position.
# - **NED10 (fits are done)** small lc component; nicely resolved mc component prior to the specimens acquiring GRM with the exception of specimens 1b and 2b that are potentially biased by the large GRM (acqured vertically in specimen coordinates) and are not fit; no hc component can be resolved.
# - **NED11 (fits are done)** lc component is present, but difficult to isolate given overlapping coercivity with the mc component; mc component is well-resolved in all specimens with the exception of specimen 1b; hc can be resolved in some of the speciments
# - **NED12 (fits are done)** nicely resolved lc, mc and hc components that are fit for each specimen. specimens 1b and 4b had issues with orientation and are marked as bad.
# - **NED13 (fits are done)** the mc component dominates with some samples with sizeable lc components with one sample with a full IRM (2b); a couple samples have resolvable hc
# - **NED14 (fits are done)** large lc component that dominates the entire remanence in 1b and 2b; resolvable mc component between lc and hc in the rest of the specimens; hc component can be fit in a couple samples with others having it be obscured by acquisition of GRM
# - **NED15 (fits are done)** well-grouped lc component to the SW and down resolvable below 4 millitesla; the mc component can be well fit prior to the specimens acquiring a GRM that obscures any hc
# - **NED16 (fits are done)** sizeable lc component; mc component can be nicely resolvable in most specimens with the exception of a couple where it is obscured by a large GRM; GRM obscures hc component
# - **NED17** baked contact test.
# - **NED18 (fits are done)** variable size lc components; mc can
# - **NED19 (fits are done)** a couple of the samples such as 8b are like the typical behavior, but majority have a large lmc component the is NE and up
# - **NED20 (fits are done)** very large lc component that then goes to hc noisy endpoint without resolvable mc component
# - **NED21 (fits are done)** same samples have very large lc component such that other components can not be fit while in some samples an mc component can be fit with a small hc endpoint that can be fit with a line anchored to the origin.
# - **NED22 (fits are done)** specimens 3a to 5a look to have a lc and hc components in a similar direction that is interupted by a mc component. since the mc component is small relative to the other signal it can not be well isolated and this site does not have an usable overall mc mean.
# - **NED23 (fits are done)** small lc in present-local field direction; nicely resolvable mc component; hc component that can be fit with an endpoint anchored to the origin
# - **NED24** only two samples have been analyzed and these data are not fit in the current analysis
# - **NED25 (fits are done)** specimens 1a, 2a, 6a, 7a, 8a have typical behavior with steep mc component that can be resolved, a distinct direction comes out of other samples in that coercivity change but persists more unidirectionally to into the hc. These are marked as bad with the subset with typical behavior being used; hc isn't well-resolved in the site although lc is roughly in the direction of hc (MCR)
# - **NED26 (fits are done)** nicely resolvable lc, mc and hc components
# - **NED27 (fits are done)** the samples dominantly only have two components — an lc and an hc. A couple samples have an mc component that influences the demagnetization, but it can only be fit in one sample
# - **NED28 (fits are done)** very large lc component, followed by coherent mc component that can go to rather high coercivity
# - **NED29 (fits are done)** small lc component in a well-grouped SW and shallow up (IRM?); resolvable mc component; heads toward hc component without that component being well-resolved, could be fit with planes, but is not currently.
# - **NED30 (fits are done)** large lc components; mc components are not well-resolved there might be a hint of it in 8a, but it can't be fit; a couple samples with smaller lc components have a MCR hc direction
# - **NED31 (fits are done)** large lc overprints on 1a and 2a; 3a, 4a and 5a have typical behavior with a nicely resolved mc component going to typical hc direction
# - **NED32 (fits are done)** large lc components that are typically single-component (with some wiggling) up through the coercivity spectra
# - **NED33 (fits are done)** the samples have lc and hc components without resolvable mc components. There is a hint of an mc component in 5a, 6a and 7a but it cannot be fit.
# - **NED34 (fits are done)** small lc component that cannot be fit with a line; large mc component that dominants the remanence; moves towards a small hc that cannot be fit
# - **NED35 (fits are done)** large mc component dominants remanance such that lc and hc are not resolved
# - **NED36 (fits are done)** small lc in PLF direction; remanence is dominated by hc component headed towards origin

# %% [markdown]
# ## Import sample-level data

# %%
specimen_data = pd.read_csv('../Data/pmag_data/specimens.txt', sep='\t',skiprows=1)
specimen_data.head()
# Out:
#   specimen        experiments  sample  dir_alpha95 dir_comp  dir_dec  dir_inc  \
# 0  NED1-1b  NED1-1b_LP-DIR-AF  NED1-1          NaN       mc    159.7     62.5
# 1  NED1-1b  NED1-1b_LP-DIR-AF  NED1-1          NaN       mc    139.2     74.1
# 2  NED1-1b                NaN  NED1-1          NaN      NaN      NaN      NaN
# 3  NED1-2b  NED1-2b_LP-DIR-AF  NED1-2          NaN       mc    164.1     66.9
# 4  NED1-2b  NED1-2b_LP-DIR-AF  NED1-2          NaN       mc    149.9     76.3
#
#    dir_n_comps  dir_n_measurements  dir_tilt_correction  dir_dang  \
# 0          1.0                 5.0                 -1.0       2.8
# 1          1.0                 5.0                  0.0       2.8
# 2          NaN                 NaN                  NaN       NaN
# 3          1.0                 7.0                 -1.0       3.4
# 4          1.0                 7.0                  0.0       3.4
#
#    dir_mad_free  meas_step_max  meas_step_min meas_step_unit  \
# 0           1.0           0.04          0.025              T
# 1           1.0           0.04          0.025              T
# 2           NaN            NaN            NaN            NaN
# 3           0.4           0.04          0.020              T
# 4           0.4           0.04          0.020              T
#
#                instrument_codes         software_packages int_corr  \
# 0  hargrave 2018-09-21 18:45:36  pmagpy-4.2.25: demag_gui        u
# 1  hargrave 2018-09-21 18:45:36  pmagpy-4.2.25: demag_gui        u
# 2                           NaN                       NaN      NaN
# 3  hargrave 2018-09-21 19:30:31  pmagpy-4.2.25: demag_gui        u
# 4  hargrave 2018-09-21 19:30:31  pmagpy-4.2.25: demag_gui        u
#
#     citations                 method_codes result_quality  volume  weight  \
# 0  This study      LP-DIR-AF:DE-BFL:DA-DIR              g     NaN     NaN
# 1  This study  LP-DIR-AF:DE-BFL:DA-DIR-GEO              g     NaN     NaN
# 2  This study                     LP-NOMAG            NaN     NaN     NaN
# 3  This study      LP-DIR-AF:DE-BFL:DA-DIR              g     NaN     NaN
# 4  This study  LP-DIR-AF:DE-BFL:DA-DIR-GEO              g     NaN     NaN
#
#   location  site
# 0     ECMB  NED1
# 1     ECMB  NED1
# 2     ECMB  NED1
# 3     ECMB  NED1
# 4     ECMB  NED1

# %% [markdown]
# ## Import site-level data

# %%
site_data = pd.read_csv('../Data/pmag_data/sites.txt', sep='\t',skiprows=1)
site_data.head(1)
# Out:
#    site location                             samples  \
# 0  NED1     ECMB  NED1-3:NED1-4:NED1-5:NED1-7:NED1-8
#
#                                  specimens   age  age_high  age_low age_unit  \
# 0  NED1-3b:NED1-4b:NED1-5b:NED1-7b:NED1-8b  1779      1782     1776       Ma
#
#    dir_alpha95 dir_comp_name  dir_dec  dir_inc  dir_k  dir_n_samples  \
# 0          9.8            lc     46.4     70.0   62.0            5.0
#
#    dir_n_specimens  dir_n_specimens_lines  dir_n_specimens_planes  \
# 0              5.0                    5.0                     0.0
#
#   dir_polarity   dir_r  dir_tilt_correction  height       lat        lon  \
# 0            n  4.9357                  0.0     0.0  45.53423  265.75804
#
#   geologic_classes geologic_types lithologies               software_packages  \
# 0        Intrusive        Diabase     Diabase  pmagpy-4.2.25: demag_gui.v.3.0
#
#     citations                              method_codes result_quality  \
# 0  This study  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g
#
#   result_type  vgp_dm  vgp_dp  vgp_lat  vgp_lon
# 0           i    16.9    14.5     59.5    322.8

# %% [markdown]
# ## Analyze NE-trending dike site-level data

# %% [markdown]
# We will not include NWD1 as it is another generation of dikes that cross cut the NED dikes.
#
# We will apply a filter of $\alpha_{95}<8$. This filter removes NED3 which has streaked directions between mc and hc component means, NED21 which only has 2 mc component fits, NED17 which is the baked contact test site and includes a shifted block, and NED 19 as there are two populations of directions and an imprecise mean for the one that corresponds with the population.

# %%
NED_site_data = site_data.drop(site_data[site_data['site']=='NWD1'].index)
NED_site_data_mc = NED_site_data[NED_site_data['dir_comp_name']=='mc']
NED_site_data_mc = NED_site_data_mc[NED_site_data_mc['dir_alpha95']<8]
NED_site_data_mc
# Out:
#      site location                                            samples  \
# 1    NED1     ECMB  NED1-1:NED1-2:NED1-3:NED1-4:NED1-5:NED1-6:NED1...
# 3   NED10     ECMB    NED10-3:NED10-4:NED10-5:NED10-6:NED10-7:NED10-8
# 6   NED11     ECMB  NED11-2:NED11-3:NED11-4:NED11-5:NED11-6:NED11-...
# 8   NED12     ECMB    NED12-1:NED12-3:NED12-5:NED12-6:NED12-7:NED12-8
# 11  NED13     ECMB  NED13-1:NED13-3:NED13-4:NED13-5:NED13-6:NED13-...
# 13  NED14     ECMB    NED14-3:NED14-4:NED14-5:NED14-7:NED14-8:NED14-9
# 15  NED15     ECMB  NED15-1:NED15-2:NED15-3:NED15-4:NED15-5:NED15-...
# 17  NED16     ECMB            NED16-2:NED16-3:NED16-4:NED16-5:NED16-8
# 25  NED18     ECMB    NED18-1:NED18-2:NED18-3:NED18-4:NED18-5:NED18-6
# 30   NED2     ECMB  NED2-1:NED2-2:NED2-3:NED2-4:NED2-5:NED2-6:NED2...
# 39  NED23     ECMB  NED23-1:NED23-2:NED23-3:NED23-4:NED23-5:NED23-...
# 43  NED25     ECMB                    NED25-1:NED25-2:NED25-6:NED25-8
# 44  NED26     ECMB            NED26-4:NED26-5:NED26-6:NED26-7:NED26-8
# 50  NED28     ECMB                    NED28-2:NED28-3:NED28-4:NED28-5
# 52  NED29     ECMB  NED29-1:NED29-2:NED29-3:NED29-5:NED29-6:NED29-...
# 58  NED31     ECMB                            NED31-3:NED31-4:NED31-5
# 64  NED34     ECMB  NED34-1:NED34-2:NED34-3:NED34-4:NED34-5:NED34-...
# 65  NED35     ECMB  NED35-1:NED35-2:NED35-3:NED35-4:NED35-6:NED35-...
# 70   NED5     ECMB          NED5-3:NED5-4:NED5-5:NED5-6:NED5-7:NED5-8
# 71   NED6     ECMB  NED6-1:NED6-2:NED6-3:NED6-4:NED6-5:NED6-6:NED6...
# 73   NED7     ECMB                 NED7-1:NED7-2:NED7-3:NED7-4:NED7-8
# 76   NED8     ECMB   NED8-1:NED8-2:NED8-3:NED8-4:NED8-5:NED8-6:NED8-7
# 78   NED9     ECMB   NED9-2:NED9-3:NED9-4:NED9-5:NED9-6:NED9-7:NED9-8
#
#                                             specimens   age  age_high  \
# 1   NED1-1b:NED1-2b:NED1-3b:NED1-4b:NED1-5b:NED1-6...  1779      1782
# 3   NED10-3b:NED10-4b:NED10-5b:NED10-6b:NED10-7b:N...  1779      1782
# 6   NED11-2b:NED11-3b:NED11-4b:NED11-5b:NED11-6b:N...  1779      1782
# 8   NED12-1b:NED12-3b:NED12-5b:NED12-6b:NED12-7b:N...  1779      1782
# 11  NED13-1b:NED13-3b:NED13-4b:NED13-5b:NED13-6b:N...  1779      1782
# 13  NED14-3b:NED14-4b:NED14-5b:NED14-7b:NED14-8b:N...  1779      1782
# 15  NED15-1b:NED15-2b:NED15-3b:NED15-4b:NED15-5b:N...  1779      1782
# 17       NED16-2b:NED16-3b:NED16-4b:NED16-5b:NED16-8b  1779      1782
# 25  NED18-1b:NED18-2b:NED18-3b:NED18-4b:NED18-5b:N...  1779      1782
# 30  NED2-1b:NED2-2b:NED2-3b:NED2-4b:NED2-5b:NED2-6...  1779      1782
# 39  NED23-1a:NED23-2a:NED23-3a:NED23-4a:NED23-5a:N...  1779      1782
# 43                NED25-1a:NED25-2a:NED25-6a:NED25-8a  1779      1782
# 44       NED26-4a:NED26-5a:NED26-6a:NED26-7a:NED26-8a  1779      1782
# 50                NED28-2a:NED28-3a:NED28-4a:NED28-5a  1779      1782
# 52  NED29-1a:NED29-2a:NED29-3a:NED29-5a:NED29-6a:N...  1779      1782
# 58                         NED31-3a:NED31-4a:NED31-5a  1779      1782
# 64  NED34-1a:NED34-2a:NED34-3a:NED34-4a:NED34-5a:N...  1779      1782
# 65  NED35-1a:NED35-2a:NED35-3a:NED35-4a:NED35-6a:N...  1779      1782
# 70    NED5-3b:NED5-4b:NED5-5b:NED5-6b:NED5-7b:NED5-8b  1779      1782
# 71  NED6-1b:NED6-2b:NED6-3b:NED6-4b:NED6-5b:NED6-6...  1779      1782
# 73            NED7-1b:NED7-2b:NED7-3b:NED7-4b:NED7-8b  1779      1782
# 76  NED8-1b:NED8-2b:NED8-3b:NED8-4b:NED8-5b:NED8-6...  1779      1782
# 78  NED9-2b:NED9-3b:NED9-4b:NED9-5b:NED9-6b:NED9-7...  1779      1782
#
#     age_low age_unit  dir_alpha95 dir_comp_name  dir_dec  dir_inc   dir_k  \
# 1      1776       Ma          2.8            mc    157.6     74.7   380.0
# 3      1776       Ma          3.7            mc    199.7     73.3   324.0
# 6      1776       Ma          3.1            mc    166.1     75.1   391.0
# 8      1776       Ma          3.5            mc    179.5     73.0   374.0
# 11     1776       Ma          4.3            mc    169.1     73.9   199.0
# 13     1776       Ma          4.6            mc    193.0     70.0   217.0
# 15     1776       Ma          2.3            mc    175.8     77.7   604.0
# 17     1776       Ma          3.6            mc    185.1     78.6   449.0
# 25     1776       Ma          5.3            mc    134.7     81.7   159.0
# 30     1776       Ma          2.7            mc    172.3     74.9   420.0
# 39     1776       Ma          3.0            mc    193.0     76.4   411.0
# 43     1776       Ma          5.0            mc    135.4     80.7   334.0
# 44     1776       Ma          3.2            mc    151.1     73.4   572.0
# 50     1776       Ma          7.7            mc    157.8     73.8   145.0
# 52     1776       Ma          5.1            mc    219.0     76.7   119.0
# 58     1776       Ma          3.0            mc    184.7     69.4  1730.0
# 64     1776       Ma          2.9            mc    185.9     77.0   362.0
# 65     1776       Ma          3.4            mc    166.4     74.7   261.0
# 70     1776       Ma          4.6            mc    170.3     79.0   213.0
# 71     1776       Ma          3.8            mc    197.8     73.6   183.0
# 73     1776       Ma          5.4            mc    266.3     81.3   204.0
# 76     1776       Ma          2.9            mc    202.6     78.6   423.0
# 78     1776       Ma          6.4            mc    191.1     71.5    90.0
#
#     dir_n_samples  dir_n_specimens  dir_n_specimens_lines  \
# 1             8.0              8.0                    8.0
# 3             6.0              6.0                    6.0
# 6             7.0              7.0                    7.0
# 8             6.0              6.0                    6.0
# 11            7.0              7.0                    7.0
# 13            6.0              6.0                    6.0
# 15            8.0              8.0                    8.0
# 17            5.0              5.0                    5.0
# 25            6.0              6.0                    6.0
# 30            8.0              8.0                    8.0
# 39            7.0              7.0                    7.0
# 43            4.0              4.0                    4.0
# 44            5.0              5.0                    5.0
# 50            4.0              4.0                    4.0
# 52            8.0              8.0                    8.0
# 58            3.0              3.0                    3.0
# 64            8.0              8.0                    8.0
# 65            8.0              8.0                    8.0
# 70            6.0              6.0                    6.0
# 71            9.0              9.0                    9.0
# 73            5.0              5.0                    5.0
# 76            7.0              7.0                    7.0
# 78            7.0              7.0                    7.0
#
#     dir_n_specimens_planes dir_polarity   dir_r  dir_tilt_correction  height  \
# 1                      0.0            t  7.9816                  0.0     0.0
# 3                      0.0            t  5.9846                  0.0     0.0
# 6                      0.0            t  6.9847                  0.0     0.0
# 8                      0.0            t  5.9866                  0.0     0.0
# 11                     0.0            t  6.9698                  0.0     0.0
# 13                     0.0            t  5.9769                  0.0     0.0
# 15                     0.0            t  7.9884                  0.0     0.0
# 17                     0.0            t  4.9911                  0.0     0.0
# 25                     0.0            t  5.9686                  0.0     0.0
# 30                     0.0            t  7.9833                  0.0     0.0
# 39                     0.0            t  6.9854                  0.0     0.0
# 43                     0.0            t  3.9910                  0.0     0.0
# 44                     0.0            t  4.9930                  0.0     0.0
# 50                     0.0            t  3.9793                  0.0     0.0
# 52                     0.0            t  7.9410                  0.0     0.0
# 58                     0.0            t  2.9988                  0.0     0.0
# 64                     0.0            t  7.9806                  0.0     0.0
# 65                     0.0            t  7.9731                  0.0     0.0
# 70                     0.0            t  5.9765                  0.0     0.0
# 71                     0.0            t  8.9564                  0.0     0.0
# 73                     0.0            n  4.9804                  0.0     0.0
# 76                     0.0            t  6.9858                  0.0     0.0
# 78                     0.0            t  6.9334                  0.0     0.0
#
#          lat        lon geologic_classes geologic_types lithologies  \
# 1   45.53423  265.75804        Intrusive        Diabase     Diabase
# 3   45.53259  265.75742        Intrusive        Diabase     Diabase
# 6   45.53252  265.75768        Intrusive        Diabase     Diabase
# 8   45.53489  265.76076        Intrusive        Diabase     Diabase
# 11  45.53497  265.76113        Intrusive        Diabase     Diabase
# 13  45.53492  265.76119        Intrusive        Diabase     Diabase
# 15  45.53688  265.76758        Intrusive        Diabase     Diabase
# 17  45.53728  265.76822        Intrusive        Diabase     Diabase
# 25  45.53124  265.76945        Intrusive        Diabase     Diabase
# 30  45.53421  265.75816        Intrusive        Diabase     Diabase
# 39  45.53398  265.74200        Intrusive        Diabase     Diabase
# 43  45.53396  265.74119        Intrusive        Diabase     Diabase
# 44  45.53445  265.74129        Intrusive        Diabase     Diabase
# 50  45.53467  265.73817        Intrusive        Diabase     Diabase
# 52  45.53438  265.73690        Intrusive        Diabase     Diabase
# 58  45.53385  265.75785        Intrusive        Diabase     Diabase
# 64  45.51700  265.78083        Intrusive        Diabase     Diabase
# 65  45.53320  265.75761        Intrusive        Diabase     Diabase
# 70  45.53309  265.75803        Intrusive        Diabase     Diabase
# 71  45.53299  265.75773        Intrusive        Diabase     Diabase
# 73  45.53288  265.75767        Intrusive        Diabase     Diabase
# 76  45.53286  265.75782        Intrusive        Diabase     Diabase
# 78  45.53314  265.75855        Intrusive        Diabase     Diabase
#
#                  software_packages   citations  \
# 1   pmagpy-4.2.25: demag_gui.v.3.0  This study
# 3   pmagpy-4.2.25: demag_gui.v.3.0  This study
# 6   pmagpy-4.2.25: demag_gui.v.3.0  This study
# 8   pmagpy-4.2.25: demag_gui.v.3.0  This study
# 11  pmagpy-4.2.25: demag_gui.v.3.0  This study
# 13  pmagpy-4.2.25: demag_gui.v.3.0  This study
# 15  pmagpy-4.2.25: demag_gui.v.3.0  This study
# 17  pmagpy-4.2.25: demag_gui.v.3.0  This study
# 25  pmagpy-4.2.25: demag_gui.v.3.0  This study
# 30  pmagpy-4.2.25: demag_gui.v.3.0  This study
# 39  pmagpy-4.2.25: demag_gui.v.3.0  This study
# 43  pmagpy-4.2.25: demag_gui.v.3.0  This study
# 44  pmagpy-4.2.25: demag_gui.v.3.0  This study
# 50  pmagpy-4.2.25: demag_gui.v.3.0  This study
# 52  pmagpy-4.2.25: demag_gui.v.3.0  This study
# 58  pmagpy-4.2.25: demag_gui.v.3.0  This study
# 64  pmagpy-4.2.25: demag_gui.v.3.0  This study
# 65  pmagpy-4.2.25: demag_gui.v.3.0  This study
# 70  pmagpy-4.2.25: demag_gui.v.3.0  This study
# 71  pmagpy-4.2.25: demag_gui.v.3.0  This study
# 73  pmagpy-4.2.25: demag_gui.v.3.0  This study
# 76  pmagpy-4.2.25: demag_gui.v.3.0  This study
# 78  pmagpy-4.2.25: demag_gui.v.3.0  This study
#
#                                 method_codes result_quality result_type  \
# 1   LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 3   LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 6   LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 8   LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 11  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 13  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 15  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 17  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 25  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 30  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 39  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 43  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 44  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 50  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 52  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 58  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 64  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 65  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 70  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 71  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 73  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 76  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
# 78  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
#
#     vgp_dm  vgp_dp  vgp_lat  vgp_lon
# 1      5.1     4.6     18.4    276.9
# 3      6.6     5.9     15.8    255.4
# 6      5.7     5.2     18.1    272.6
# 8      6.2     5.6     14.1    266.0
# 11     7.8     7.0     15.9    271.4
# 13     7.9     6.8     10.1    258.0
# 15     4.3     4.0     22.0    267.6
# 17     6.8     6.4     23.6    263.7
# 25    10.3    10.0     33.2    279.5
# 30     4.9     4.5     17.4    269.6
# 39     5.6     5.1     20.2    259.7
# 43     9.6     9.3     31.5    280.6
# 44     5.7     5.1     17.4    280.8
# 50    13.9    12.5     16.9    277.2
# 52     9.5     8.8     24.4    248.6
# 58     5.1     4.4      8.7    262.9
# 64     5.4     5.0     20.8    263.1
# 65     6.2     5.6     17.4    272.6
# 70     8.7     8.3     24.5    269.6
# 71     6.8     6.1     16.1    256.5
# 73    10.4    10.1     42.0    242.6
# 76     5.5     5.2     24.8    256.6
# 78    11.2     9.8     12.2    259.5

# %% [markdown]
# ### Export site mean latex table

# %%
columns=['site',
         'lat',
         'lon',
         'dir_n_samples',
         'dir_dec',
         'dir_inc',
         'dir_k',
         'dir_r',
         'dir_alpha95',
         'vgp_lat',
         'vgp_lon']

formatters=[None,
            "{:0.5f}".format,
            "{:0.5f}".format,
            "{:0.0f}".format,
            "{:0.1f}".format,
            "{:0.1f}".format,
            "{:0.0f}".format,
            "{:0.2f}".format,            
            "{:0.1f}".format,
            "{:0.1f}".format,
            "{:0.1f}".format]

#export at tens place for most columns
NED_site_data_mc[columns].to_latex(columns=columns,index=False,formatters=formatters)
# Out:
# '\\begin{tabular}{lrrrrrrrrrr}\n\\toprule\n  site &      lat &       lon & dir\\_n\\_samples & dir\\_dec & dir\\_inc & dir\\_k & dir\\_r & dir\\_alpha95 & vgp\\_lat & vgp\\_lon \\\\\n\\midrule\n  NED1 & 45.53423 & 265.75804 &             8 &   157.6 &    74.7 &   380 &  7.98 &         2.8 &    18.4 &   276.9 \\\\\n NED10 & 45.53259 & 265.75742 &             6 &   199.7 &    73.3 &   324 &  5.98 &         3.7 &    15.8 &   255.4 \\\\\n NED11 & 45.53252 & 265.75768 &             7 &   166.1 &    75.1 &   391 &  6.98 &         3.1 &    18.1 &   272.6 \\\\\n NED12 & 45.53489 & 265.76076 &             6 &   179.5 &    73.0 &   374 &  5.99 &         3.5 &    14.1 &   266.0 \\\\\n NED13 & 45.53497 & 265.76113 &             7 &   169.1 &    73.9 &   199 &  6.97 &         4.3 &    15.9 &   271.4 \\\\\n NED14 & 45.53492 & 265.76119 &             6 &   193.0 &    70.0 &   217 &  5.98 &         4.6 &    10.1 &   258.0 \\\\\n NED15 & 45.53688 & 265.76758 &             8 &   175.8 &    77.7 &   604 &  7.99 &         2.3 &    22.0 &   267.6 \\\\\n NED16 & 45.53728 & 265.76822 &             5 &   185.1 &    78.6 &   449 &  4.99 &         3.6 &    23.6 &   263.7 \\\\\n NED18 & 45.53124 & 265.76945 &             6 &   134.7 &    81.7 &   159 &  5.97 &         5.3 &    33.2 &   279.5 \\\\\n  NED2 & 45.53421 & 265.75816 &             8 &   172.3 &    74.9 &   420 &  7.98 &         2.7 &    17.4 &   269.6 \\\\\n NED23 & 45.53398 & 265.74200 &             7 &   193.0 &    76.4 &   411 &  6.99 &         3.0 &    20.2 &   259.7 \\\\\n NED25 & 45.53396 & 265.74119 &             4 &   135.4 &    80.7 &   334 &  3.99 &         5.0 &    31.5 &   280.6 \\\\\n NED26 & 45.53445 & 265.74129 &             5 &   151.1 &    73.4 &   572 &  4.99 &         3.2 &    17.4 &   280.8 \\\\\n NED28 & 45.53467 & 265.73817 &             4 &   157.8 &    73.8 &   145 &  3.98 &         7.7 &    16.9 &   277.2 \\\\\n NED29 & 45.53438 & 265.73690 &             8 &   219.0 &    76.7 &   119 &  7.94 &         5.1 &    24.4 &   248.6 \\\\\n NED31 & 45.53385 & 265.75785 &             3 &   184.7 &    69.4 &  1730 &  3.00 &         3.0 &     8.7 &   262.9 \\\\\n NED34 & 45.51700 & 265.78083 &             8 &   185.9 &    77.0 &   362 &  7.98 &         2.9 &    20.8 &   263.1 \\\\\n NED35 & 45.53320 & 265.75761 &             8 &   166.4 &    74.7 &   261 &  7.97 &         3.4 &    17.4 &   272.6 \\\\\n  NED5 & 45.53309 & 265.75803 &             6 &   170.3 &    79.0 &   213 &  5.98 &         4.6 &    24.5 &   269.6 \\\\\n  NED6 & 45.53299 & 265.75773 &             9 &   197.8 &    73.6 &   183 &  8.96 &         3.8 &    16.1 &   256.5 \\\\\n  NED7 & 45.53288 & 265.75767 &             5 &   266.3 &    81.3 &   204 &  4.98 &         5.4 &    42.0 &   242.6 \\\\\n  NED8 & 45.53286 & 265.75782 &             7 &   202.6 &    78.6 &   423 &  6.99 &         2.9 &    24.8 &   256.6 \\\\\n  NED9 & 45.53314 & 265.75855 &             7 &   191.1 &    71.5 &    90 &  6.93 &         6.4 &    12.2 &   259.5 \\\\\n\\bottomrule\n\\end{tabular}\n'

# %%
NWD_site_data = site_data[site_data['site']=='NWD1']
NWD_site_data_mc = NWD_site_data[NWD_site_data['dir_comp_name']=='mc']
NWD_site_data_mc
# Out:
#     site location                                            samples  \
# 82  NWD1     ECMB  NWD1-11:NWD1-12:NWD1-13:NWD1-14:NWD1-15:NWD1-1...
#
#                                             specimens   age  age_high  \
# 82  NWD1-11b:NWD1-12b:NWD1-13a:NWD1-14a:NWD1-15a:N...  1095      1100
#
#     age_low age_unit  dir_alpha95 dir_comp_name  dir_dec  dir_inc  dir_k  \
# 82     1090       Ma          6.4            mc    293.4     41.6   66.0
#
#     dir_n_samples  dir_n_specimens  dir_n_specimens_lines  \
# 82            9.0              9.0                    9.0
#
#     dir_n_specimens_planes dir_polarity   dir_r  dir_tilt_correction  height  \
# 82                     0.0            t  8.8792                  0.0     0.0
#
#          lat        lon geologic_classes geologic_types lithologies  \
# 82  45.53407  265.76852        Intrusive        Diabase     Diabase
#
#                  software_packages   citations  \
# 82  pmagpy-4.2.25: demag_gui.v.3.0  This study
#
#                                 method_codes result_quality result_type  \
# 82  LP-DIR-AF:DE-BFL:DA-DIR-GEO:LP-DC4:DE-FM              g           i
#
#     vgp_dm  vgp_dp  vgp_lat  vgp_lon
# 82     7.8     4.8     32.9    177.5

# %%
NWD_site_data_mc[columns].to_latex(columns=columns,index=False,formatters=formatters)
# Out:
# '\\begin{tabular}{lrrrrrrrrrr}\n\\toprule\n site &      lat &       lon & dir\\_n\\_samples & dir\\_dec & dir\\_inc & dir\\_k & dir\\_r & dir\\_alpha95 & vgp\\_lat & vgp\\_lon \\\\\n\\midrule\n NWD1 & 45.53407 & 265.76852 &             9 &   293.4 &    41.6 &    66 &  8.88 &         6.4 &    32.9 &   177.5 \\\\\n\\bottomrule\n\\end{tabular}\n'

# %% [markdown]
# ### Plot results and calculate mean pole

# %%
NED_site_data_mc_dec = NED_site_data_mc['dir_dec'].tolist()
NED_site_data_mc_inc = NED_site_data_mc['dir_inc'].tolist()
NED_site_data_mc_a95 = NED_site_data_mc['dir_alpha95'].tolist()

NED_site_data_mc_vgp_lat = NED_site_data_mc['vgp_lat'].tolist()
NED_site_data_mc_vgp_lon = NED_site_data_mc['vgp_lon'].tolist()

# %%
plt.figure(figsize=(6,6))
ipmag.plot_net()
for n in range(0,len(NED_site_data_mc_dec)):
    ipmag.plot_di_mean(NED_site_data_mc_dec[n],NED_site_data_mc_inc[n],NED_site_data_mc_a95[n],
                       color=[.01,.01,.01])
ipmag.plot_di(NED_site_data_mc_dec[0],NED_site_data_mc_inc[0],label='NED site means')
plt.legend(fontsize='xx-large',loc='lower center',bbox_to_anchor=(0.5,0.05))
plt.savefig('visualizations/mc_site_mean_directions.pdf')
plt.show()

plt.figure(figsize=(6,6))
ipmag.plot_net()
ipmag.plot_di(NED_site_data_mc_dec,NED_site_data_mc_inc)
plt.show()

# %%
NED_pole = ipmag.fisher_mean(NED_site_data_mc_vgp_lon,NED_site_data_mc_vgp_lat)
NED_pole
# Out:
# {'dec': 265.8158044859281,
#  'inc': 20.48669733354535,
#  'n': 23,
#  'r': 22.51800539199423,
#  'k': 45.64366412940581,
#  'alpha95': 4.528967055678733,
#  'csd': 11.989325978336389}

# %%
map_axis = ipmag.make_orthographic_map(central_longitude=270,central_latitude=30,
                                       land_edge_color=None)
ipmag.plot_vgp(map_axis,-94.2,45.5,color='tomato',marker='*',markersize=140,label='study area')
ipmag.plot_vgp(map_axis,NED_site_data_mc_vgp_lon,NED_site_data_mc_vgp_lat,
               color='grey',markersize=40,label='ECMB VGPs')
ipmag.plot_pole(map_axis,NED_pole['dec'],NED_pole['inc'],NED_pole['alpha95'],
                marker='s',color='steelblue',markersize=50,label='ECMB mean pole')
plt.legend(fontsize='x-large',loc='lower center')
plt.savefig('visualizations/NED_pole.pdf')

# %% [markdown]
# ### Test if VGP distribution is Fisherian

# %%
ipmag.fishqq(NED_site_data_mc_vgp_lon,NED_site_data_mc_vgp_lat)
# Out:
# {'Mode': 'Mode 1',
#  'Dec': 265.8884717903875,
#  'Inc': 20.34204782343405,
#  'N': 23,
#  'Mu': -0.292357897495827,
#  'Mu_critical': 1.207,
#  'Me': 0.4871528846381723,
#  'Me_critical': 1.094,
#  'Test_result': 'consistent with Fisherian model'}

# %%
duluth_lat = 46.8
duluth_lon = 267.9

ipmag.lat_from_pole(duluth_lon,duluth_lat,NED_pole['dec'],NED_pole['inc'])
# Out:
# 63.63191909904516

# %% [markdown]
# ## Plotting the direction of the NW-trending dike and NE-trending dike hc component

# %%
NWD_mc = site_data[(site_data['site']=='NWD1') & (site_data['dir_comp_name']=='mc')]

site_data_hc = site_data[site_data['dir_comp_name']=='hc']
site_data_hc = site_data_hc[site_data_hc['dir_alpha95']<30]
#site_data_hc = site_data_hc[site_data_hc['dir_n_specimens']>2]

site_data_hc_dec = site_data_hc['dir_dec'].tolist()
site_data_hc_inc = site_data_hc['dir_inc'].tolist()
site_data_hc_a95 = site_data_hc['dir_alpha95'].tolist()

# %%
plt.figure(figsize=(6,6))
ipmag.plot_net()
for n in range(0,len(site_data_hc_dec)):
    ipmag.plot_di_mean(site_data_hc_dec[n],site_data_hc_inc[n],site_data_hc_a95[n],
                       color=[.01,.01,.01])
    
ipmag.plot_di(NWD_mc['dir_dec'].tolist()[0],NWD_mc['dir_inc'].tolist()[0],
              label='NE-trending dikes high-coercivity direction',color='black')

ipmag.plot_di_mean(NWD_mc['dir_dec'].tolist()[0],NWD_mc['dir_inc'].tolist()[0],
                   NWD_mc['dir_alpha95'].tolist()[0],color='red')
ipmag.plot_di(NWD_mc['dir_dec'].tolist()[0],NWD_mc['dir_inc'].tolist()[0],
              label='NW-trending dike magnetite direction',color='red',marker='s')
plt.legend(fontsize='x-large',loc='lower center')
plt.savefig('visualizations/hc_site_mean_directions.pdf')
plt.show()

# %% [markdown]
# ## Compare with Cleaver dike pole VGPs

# %%
Cleaver_sites = pd.read_csv('../Data/pole_compilations/Irving2004_Cleaver.csv')
Cleaver_sites = Cleaver_sites[(Cleaver_sites.site != 27) & (Cleaver_sites.site != 24) & (Cleaver_sites.site != 32) & (Cleaver_sites.site != 33) & (Cleaver_sites.site != 35) & (Cleaver_sites.site != 36) & (Cleaver_sites.site != 45)]

# %% [markdown]
# The following sites are not included in Irving et al. 2004 Cleaver Dike pole:
#
# - Site 24 is volcanic breccia
# - Site 32 is a baked tuff at contact of dyke 22.
# - Site 33 is a tuff at distance of 25m from dyke 22.
# - Site 35 baked andesite at contact of dyke 34.
# - Site 36 andesite 50m from dyke 34.
# - Site 45 Gunbarrel Gabbro.
# - Site 27 is not described as being excluded, but it is excluded as there are only 17 dikes in the mean and was it is removed the Fisher mean is the same as reported in the Irving et al. 2004 paper. It is likely excluded due to an a_95 of 10

# %%
ipmag.fisher_mean(Cleaver_sites.dec_is.tolist(),Cleaver_sites.inc_is.tolist())
# Out:
# {'dec': 136.51006679590233,
#  'inc': 57.38229461486087,
#  'n': 17,
#  'r': 16.751406437475655,
#  'k': 64.36208499338396,
#  'alpha95': 4.480276059885312,
#  'csd': 10.096479472204122}

# %%
plt.figure(figsize=(6,6))
ipmag.plot_net()
for i in Cleaver_sites.index:
    ipmag.plot_di_mean(Cleaver_sites.dec_is[i],Cleaver_sites.inc_is[i],Cleaver_sites.alpha_95[i],
                       color=[.01,.01,.01])
plt.show()

# %%
ipmag.vgp_calc(Cleaver_sites,tilt_correction='no')
# Out:
#     site  site_lat  site_lon  n_samples  n_specimens    NRM  dec_is  inc_is  \
# 0      5     65.72   -118.13          6           12   2.00   132.1    64.6
# 1      6     65.72   -118.08          5           10   0.07   168.0    65.3
# 2      8     65.70   -118.13          6           11  13.10   147.2    51.3
# 3      9     65.68   -118.15          6           12   6.45   143.5    49.7
# 4     10     65.63   -117.88          6           12   2.91   143.4    68.4
# 5     15     65.62   -118.02          6           12   3.51   126.2    56.8
# 6     18     65.79   -118.08          6           10   2.51   141.5    53.0
# 7     19     65.79   -118.07          6            8   0.35   116.9    52.6
# 8     21     65.70   -118.07          6           12   1.89   162.0    52.9
# 9     22     65.70   -118.07          6           12   3.12   136.1    59.8
# 10    23     65.70   -118.07          6           12  17.90   124.9    53.9
# 11    26     65.63   -118.12          6           12   6.60   151.2    57.2
# 13    30     65.63   -118.13          6           11   6.47   146.6    53.3
# 14    31     65.58   -117.98          3            6   4.82   118.0    50.6
# 15    34     65.70   -118.05          7           13   5.17   130.7    59.6
# 16    37     65.67   -118.13          6           11   4.90   114.3    51.0
# 17   172     66.05   -117.83          8           15   6.13   129.1    60.5
#
#       k  alpha_95  paleolatitude    vgp_lat     vgp_lon  vgp_lat_rev  \
# 0    53       6.0      46.478746  28.108473  277.268641   -28.108473
# 1    39       7.9      47.389134  23.488634  250.748458   -23.488634
# 2   117       4.2      31.968370  10.900148  269.774324   -10.900148
# 3   107       4.2      30.522741  10.231827  273.227679   -10.231827
# 4    67       5.4      51.625846  30.562254  267.577961   -30.562254
# 5   177       3.3      37.382725  21.055888  285.379818   -21.055888
# 6   118       4.5      33.565165  13.699967  274.189682   -13.699967
# 7    33       9.7      33.183597  20.115103  294.570797   -20.115103
# 8   143       3.6      33.469429  10.145916  257.111104   -10.145916
# 9    90       4.6      40.665414  21.653399  276.394696   -21.653399
# 10  155       3.5      34.437308  18.736668  287.513348   -18.736668
# 11  151       3.5      37.806031  15.824117  265.184757   -15.824117
# 13   51       6.5      33.853767  12.788989  269.825326   -12.788989
# 14  145       5.6      31.329291  17.917663  294.454010   -17.917663
# 15  266       2.5      40.438611  22.763377  280.687762   -22.763377
# 16  202       3.2      31.693197  19.539327  297.243796   -19.539327
# 17   69       4.6      41.468544  24.415754  281.858861   -24.415754
#
#     vgp_lon_rev
# 0     97.268641
# 1     70.748458
# 2     89.774324
# 3     93.227679
# 4     87.577961
# 5    105.379818
# 6     94.189682
# 7    114.570797
# 8     77.111104
# 9     96.394696
# 10   107.513348
# 11    85.184757
# 13    89.825326
# 14   114.454010
# 15   100.687762
# 16   117.243796
# 17   101.858861

# %%
Cleaver_pole = ipmag.fisher_mean(Cleaver_sites['vgp_lon'].tolist(),Cleaver_sites['vgp_lat'].tolist())
Cleaver_pole
# Out:
# {'dec': 276.6268816988298,
#  'inc': 19.364479939581486,
#  'n': 17,
#  'r': 16.550437496311094,
#  'k': 35.59015680514113,
#  'alpha95': 6.062723373024966,
#  'csd': 13.577508024999728}

# %%
pmag.angle([Cleaver_pole['dec'],Cleaver_pole['inc']],[NED_pole['dec'],NED_pole['inc']])
# Out:
# array([10.22367729])

# %%
map_axis = ipmag.make_orthographic_map(central_longitude=260,central_latitude=20)
ipmag.plot_vgp(map_axis,NED_site_data_mc_vgp_lon,NED_site_data_mc_vgp_lat,
               color='steelblue',markersize=40,label='NED VGPs')
ipmag.plot_vgp(map_axis,Cleaver_sites['vgp_lon'],Cleaver_sites['vgp_lat'],
               color='orange',markersize=40,label='Cleaver VGPs')
plt.legend(fontsize='xx-large',loc='lower center')
plt.show()

# %%
NED_VGPs = ipmag.make_di_block(NED_site_data_mc_vgp_lon,NED_site_data_mc_vgp_lat)
Cleaver_VGPs = ipmag.make_di_block(Cleaver_sites['vgp_lon'].tolist(),Cleaver_sites['vgp_lat'].tolist())

ipmag.common_mean_watson(NED_VGPs,Cleaver_VGPs)
ipmag.common_mean_bootstrap(NED_VGPs,Cleaver_VGPs)
# Out:
# Results of Watson V test:
#
# Watson's V:           11.9
# Critical value of V:  6.3
# "Fail": Since V is greater than Vcrit, the two means can
# be distinguished at the 95% confidence level.
#
# M&M1990 classification:
#
# Angle between data set means: 10.2
# Critical angle for M&M1990:   7.4

# %%
ipmag.upload_magic(dir_path='../data/pmag_data/')
# Out:
# -I- Removing old error files from /Users/yimingzhang/Github/2021_ECMB/data/pmag_data: locations_errors.txt, samples_errors.txt, specimens_errors.txt, sites_errors.txt, ages_errors.txt, measurements_errors.txt, criteria_errors.txt, contribution_errors.txt, images_errors.txt
# -I- Using online data model
# -I- Getting method codes from earthref.org
# -I- Importing controlled vocabularies from https://earthref.org
# -W- Column 'core_depth' isn't in samples table, skipping it
# -W- Column 'composite_depth' isn't in samples table, skipping it
# -W- Invalid or missing column names, could not propagate columns
# -I- locations file successfully read in
# -I- Validating locations
# -I- No row errors found!
# -I- appending locations data to /Users/yimingzhang/Github/2021_ECMB/data/pmag_data/upload.txt
# -I- 1 records written to locations file
# -I- locations written to  /Users/yimingzhang/Github/2021_ECMB/data/pmag_data/upload.txt
# -I- measurements file successfully read in
# -I- Validating measurements
# -W- these rows have problems: row: 12410, name: None
# row: 12411, name: None
# -W- these columns contain bad values: specimen
# -I- Complete list of row errors can be found in /Users/yimingzhang/Github/2021_ECMB/data/pmag_data/measurements_errors.txt
# -I- appending measurements data to /Users/yimingzhang/Github/2021_ECMB/data/pmag_data/upload.txt
# -I- 12412 records written to measurements file
# -I- measurements written to  /Users/yimingzhang/Github/2021_ECMB/data/pmag_data/upload.txt
# -I- samples file successfully read in
# -I- Validating samples
# -I- No row errors found!
# -I- appending samples data to /Users/yimingzhang/Github/2021_ECMB/data/pmag_data/upload.txt
# -I- 312 records written to samples file
# -I- samples written to  /Users/yimingzhang/Github/2021_ECMB/data/pmag_data/upload.txt
# -I- sites file successfully read in
# -I- Validating sites
# -I- No row errors found!
# -I- appending sites data to /Users/yimingzhang/Github/2021_ECMB/data/pmag_data/upload.txt
# -I- 90 records written to sites file
# -I- sites written to  /Users/yimingzhang/Github/2021_ECMB/data/pmag_data/upload.txt
# -I- specimens file successfully read in
# -I- dropping these columns: location, site from the specimens table
# -I- Validating specimens
# -I- No row errors found!
# -I- appending specimens data to /Users/yimingzhang/Github/2021_ECMB/data/pmag_data/upload.txt
# -I- 1559 records written to specimens file
# -I- specimens written to  /Users/yimingzhang/Github/2021_ECMB/data/pmag_data/upload.txt
# Finished preparing upload file: /Users/yimingzhang/Github/2021_ECMB/data/pmag_data/ECMB_28.Jan.2021_1.txt
# -W- These tables have errors: measurements
# -W- validation of upload file has failed.
# You can still upload /Users/yimingzhang/Github/2021_ECMB/data/pmag_data/ECMB_28.Jan.2021_1.txt to MagIC,
# but you will need to fix the above errors before your contribution can be activated.
# (False,
#  'Validation of your upload file has failed.\nYou can still upload /Users/yimingzhang/Github/2021_ECMB/data/pmag_data/ECMB_28.Jan.2021_1.txt to MagIC,\nbut you will need to fix the above errors before your contribution can be activated.',
#  ['measurements'],
#  {'measurements': {'rows':                     num                           value_pass_specimen_isIn  \
#    measurement name
#    None              12410  This value: "unknown" is not found in: specime...
#    None              12411  This value: "unknown" is not found in: specime...
#
#                                                                 issues
#    measurement name
#    None              {'value_pass_specimen_isIn': 'This value: "unk...
#    None              {'value_pass_specimen_isIn': 'This value: "unk...  ,
#    'missing_columns': [],
#    'missing_groups': Index([], dtype='object')}})

# %% [markdown]
# ## Pole comparison between the NWD dike VGP and the Keweenawan track compilation

# %%
Laurentia_poles = pd.read_csv('../data/pole_compilations/Laurentia-poles.csv')[:20]
Laurentia_poles
# Out:
#                                               name    terrane     age  \
# 0                        Ontario lamprophyre dykes  Laurentia  1143.0
# 1                                    Abitibi Dykes  Laurentia  1141.0
# 2                          Nipigon sills and lavas  Laurentia  1109.0
# 3           Lowermost Mamainse Point volcanics -R1  Laurentia  1109.0
# 4                         Lower Osler volcanics -R  Laurentia  1108.0
# 5                        Middle Osler volcanics -R  Laurentia  1107.0
# 6                         Upper Osler volcanics -R  Laurentia  1105.0
# 7               Lower Mamainse Point volcanics -R2  Laurentia  1105.0
# 8   Mamainse Point volcanics -C (lower N, upper R)  Laurentia  1101.0
# 9                             North Shore lavas -N  Laurentia  1097.0
# 10                          Portage Lake Volcanics  Laurentia  1095.0
# 11                           Chengwatana Volcanics  Laurentia  1095.0
# 12           Uppermost Mamainse Point volcanics -N  Laurentia  1094.0
# 13                 Cardenas Basalts and Intrusions  Laurentia  1091.0
# 14                        Schroeder Lutsen Basalts  Laurentia  1090.0
# 15                     Central Arizona diabases -N  Laurentia  1088.0
# 16                                Lake Shore Traps  Laurentia  1086.0
# 17                   Michipicoten Island Formation  Laurentia  1084.0
# 18                                  Nonesuch Shale  Laurentia  1080.0
# 19                                 Freda Sandstone  Laurentia  1070.0
#
#     age upper  age lower  plat   plon   a95   f  slat   slon  dec  inc  \
# 0        10.0       10.0  58.0  223.3   9.2 NaN  48.8  273.3  NaN  NaN
# 1         2.0        2.0  48.8  215.5  14.1 NaN  48.0  279.0  NaN  NaN
# 2         2.0        2.0  47.2  217.8   4.0 NaN  49.1  270.9  NaN  NaN
# 3         2.0        3.0  49.5  227.0   5.3 NaN  47.1  275.3  NaN  NaN
# 4         3.0        3.0  40.9  218.6   4.8 NaN  48.8  272.3  NaN  NaN
# 5         4.0        4.0  42.7  211.3   8.2 NaN  48.8  272.4  NaN  NaN
# 6         1.0        1.0  42.3  203.4   3.7 NaN  48.7  272.4  NaN  NaN
# 7         3.0        4.0  37.5  205.2   4.5 NaN  47.1  275.3  NaN  NaN
# 8         1.0        1.0  36.1  189.7   4.9 NaN  47.1  275.3  NaN  NaN
# 9         3.0        3.0  31.1  181.7   2.1 NaN  46.3  268.7  NaN  NaN
# 10        3.0        3.0  27.5  182.5   2.3 NaN  47.0  271.2  NaN  NaN
# 11        2.0        2.0  30.9  186.1   8.2 NaN  45.4  267.3  NaN  NaN
# 12        6.0        4.0  31.2  183.2   2.5 NaN  47.1  275.3  NaN  NaN
# 13        5.0        5.0  32.0  185.0   8.0 NaN  36.1  248.1  NaN  NaN
# 14        2.0        7.0  27.1  187.8   3.0 NaN  47.5  269.1  NaN  NaN
# 15       11.0       11.0  15.7  175.3   7.0 NaN  33.7  249.2  NaN  NaN
# 16        1.0        1.0  23.1  186.4   4.0 NaN  47.6  271.9  NaN  NaN
# 17        1.0        1.0  17.0  174.7   4.4 NaN  47.7  274.3  NaN  NaN
# 18        4.0       10.0   7.6  178.1   5.5 NaN  47.0  271.5  NaN  NaN
# 19       14.0       10.0   2.2  179.0   4.2 NaN  47.0  271.5  NaN  NaN
#
#     dir_a95                                           pole ref age ref grade  \
# 0       NaN                                 \cite{Piispa2018a}     NaN    NR
# 1       NaN                                  \cite{Ernst1993a}     NaN     A
# 2       NaN  Nordic workshop calculation based on data of \...     NaN     A
# 3       NaN                         \cite{Swanson-Hysell2014a}     NaN     A
# 4       NaN                         \cite{Swanson-Hysell2014b}     NaN     A
# 5       NaN                         \cite{Swanson-Hysell2014b}     NaN     A
# 6       NaN  \cite{Halls1974a, Swanson-Hysell2014b,  Swanso...     NaN     A
# 7       NaN                         \cite{Swanson-Hysell2014a}     NaN     A
# 8       NaN                         \cite{Swanson-Hysell2014a}     NaN     A
# 9       NaN             \cite{Tauxe2009a, Swanson-Hysell2019a}     NaN     A
# 10      NaN  \cite{Books1972a, Hnat2006a} as calculated in ...     NaN     A
# 11      NaN                                   \cite{Kean1997a}     NaN     B
# 12      NaN                         \cite{Swanson-Hysell2014a}     NaN     A
# 13      NaN                                   \cite{Weil2003a}     NaN     B
# 14      NaN                              \cite{Fairchild2017a}     NaN     A
# 15      NaN                               \cite{Donadini2011b}     NaN     A
# 16      NaN                                \cite{Kulakov2013a}     NaN     A
# 17      NaN                              \cite{Fairchild2017a}     NaN     A
# 18      NaN                                  \cite{Henry1977a}     NaN     B
# 19      NaN                                  \cite{Henry1977a}     NaN     B
#
#    note  plateID
# 0   NaN      101
# 1   NaN      101
# 2   NaN      101
# 3   NaN      101
# 4   NaN      101
# 5   NaN      101
# 6   NaN      101
# 7   NaN      101
# 8   NaN      101
# 9   NaN      101
# 10  NaN      101
# 11  NaN      101
# 12  NaN      101
# 13  NaN      101
# 14  NaN      101
# 15  NaN      101
# 16  NaN      101
# 17  NaN      101
# 18  NaN      101
# 19  NaN      101

# %%
map_axis = ipmag.make_orthographic_map(central_longitude=200,central_latitude=30)
ipmag.plot_vgp(map_axis,NWD_mc['vgp_lon'].tolist(),NWD_mc['vgp_lat'].tolist(), marker ='s',
               color='red',markersize=80,label='NWD VGP')
for i in Laurentia_poles.index:
    ipmag.plot_pole(map_axis, Laurentia_poles['plon'][i], Laurentia_poles['plat'][i], Laurentia_poles['a95'][i])

ipmag.plot_poles_colorbar(map_axis,Laurentia_poles['plon'].tolist(),Laurentia_poles['plat'].tolist(),
                          Laurentia_poles['a95'],Laurentia_poles['age'].tolist(),
                          1070, 1143,marker='o',colorbar=True,colormap='viridis')

plt.legend(fontsize='xx-large',loc='lower center')
plt.show()

# %% [markdown]
# ## Pole comparison between the NWD dike VGP and the Duluth Complex ca. 1096 Ma pole
#
# The Duluth Complex mean pole position is 35.6°N, 188.7°E, N = 24, A95 = 3.1, k = 92.
#
# The VGP of the NWD dike is similar to the Duluth Complex pole position, allowing for the interpretation that the NWD dike has an emaplcement age of $ca.$ 1096 Ma.
#
# Citation: Swanson-Hysell, N.L., et al., 2020, Rapid emplacement of massive Duluth Complex intrusions within the North American Midcontinent Rift: Geology, v. 49, https://doi.org/10.1130/G47873.1

# %%
map_axis = ipmag.make_orthographic_map(central_longitude=200,central_latitude=30)
ipmag.plot_vgp(map_axis,NWD_mc['vgp_lon'].tolist(),NWD_mc['vgp_lat'].tolist(), marker = 's',
               color='red',markersize=80,label='NWD VGP')
ipmag.plot_pole(map_axis, 188.7, 35.6, 3.1, marker = 'o', color = 'darkblue',  markersize = 40, label = 'Duluth Complex pole')

plt.legend(fontsize='xx-large',loc='lower center')
plt.show()
